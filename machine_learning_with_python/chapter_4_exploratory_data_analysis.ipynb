# %%
# Kennedi Todd
# August 1, 2024
# Chapter 4: Exploratory Data Analysis

# libraries
import pandas as pd
import seaborn as sns
# %matplotlib inline

# read data
df = pd.read_csv('listings_berlin.csv')

# explore data
df.head()
# Out:
#      id                                               name  host_id host_name  \
# 0  1944         bright & airy Pberg/Mitte 3 months or more     2164     Lulah
# 1  2015   Berlin-Mitte Value! Quiet courtyard/very central     2217       Ion
# 2  3176                    Fabulous Flat in great Location     3718    Britta
# 3  3309                  BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  6883  Stylish East Side Loft in Center with AC & 2 b...    16149   Steffen
#
#         neighbourhood_group             neighbourhood  latitude  longitude  \
# 0                     Mitte          Brunnenstr. Nord  52.54433   13.39761
# 1                     Mitte           Brunnenstr. Süd  52.53305   13.40394
# 2                    Pankow   Prenzlauer Berg Südwest  52.53471   13.41810
# 3    Tempelhof - Schöneberg           Schöneberg-Nord  52.49884   13.34940
# 4  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK  52.51163   13.45289
#
# ...

# %%
df.tail()
# Out:
#              id                                      name   host_id host_name  \
# 19090  50972604          Enjoy Berlin at the best place !  79948380   Ricardo
# 19091  50977125        Zentrale 2-Zimmerwohnung in Berlin  63062620     Jonas
# 19092  50982452  Beautiful room in spacious Neukölln flat   7517055     Laura
# 19093  50982997             Central in the capital berlin  76282923    Zarina
# 19094  50983374                   Studio Komfort für Zwei  71613847      Anne
#
#           neighbourhood_group             neighbourhood   latitude  longitude  \
# 19090                   Mitte               Parkviertel  52.548600  13.351634
# 19091  Tempelhof - Schöneberg           Schöneberg-Nord  52.501473  13.354805
# 19092                Neukölln  Neuköllner Mitte/Zentrum  52.480657  13.427291
# 19093                   Mitte            Alexanderplatz  52.527802  13.408350
# 19094      Treptow - Köpenick           Oberschöneweide  52.461278  13.518873
#
# ...

# %%
df.shape
# Out:
# (19095, 16)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.describe() # by default excluded non-numeric values
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  1.909500e+04  1.909500e+04  19095.000000  19095.000000  19095.000000
# mean   2.512174e+07  9.302362e+07     52.510215     13.404654     73.303221
# std    1.492085e+07  1.071839e+08      0.032391      0.062953    136.249622
# min    1.944000e+03  1.581000e+03     52.340070     13.097150      0.000000
# 25%    1.222209e+07  1.180492e+07     52.489710     13.367160     35.000000
# 50%    2.364643e+07  4.377035e+07     52.509950     13.414090     52.000000
# 75%    3.886012e+07  1.445742e+08     52.533320     13.438900     81.000000
# max    5.098337e+07  4.120595e+08     52.656110     13.757370   8000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    19095.000000       19095.000000       14940.000000
# mean         9.105944          21.637078           0.718274
# std         33.635956          48.670427           1.445272
# ...

# %%
df.describe(include = 'all')
# Out:
#                   id                              name       host_id  \
# count   1.909500e+04                             19065  1.909500e+04
# unique           NaN                             18545           NaN
# top              NaN  Deluxe Apartment in Berlin Mitte           NaN
# freq             NaN                                20           NaN
# mean    2.512174e+07                               NaN  9.302362e+07
# std     1.492085e+07                               NaN  1.071839e+08
# min     1.944000e+03                               NaN  1.581000e+03
# 25%     1.222209e+07                               NaN  1.180492e+07
# 50%     2.364643e+07                               NaN  4.377035e+07
# 75%     3.886012e+07                               NaN  1.445742e+08
# max     5.098337e+07                               NaN  4.120595e+08
#
#        host_name       neighbourhood_group             neighbourhood  \
# ...

# %%
# pairplot
sns.pairplot(df,
             vars = ['price','number_of_reviews','availability_365'])

# %%
# heatmap
df_corr = df.corr(numeric_only = True)
sns.heatmap(df_corr,
           annot = True,
           cmap = 'coolwarm')
# Out:
# <Axes: >
